# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fake = pd.read_csv("C:\\Users\\nisarg\\OneDrive\\Desktop\\data science\\fake_news\\Fake.csv")
true = pd.read_csv("C:\\Users\\nisarg\\OneDrive\\Desktop\\data science\\fake_news\\True.csv")
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
print(fake.shape)
print(true.shape)
# Out:
# (23481, 4)
# (21417, 4)

# %%
fake['label']=0
true['label']=1

# %%
df=pd.concat([fake,true],ignore_index=True)

# %%
df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44898 entries, 0 to 44897
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44898 non-null  object
#  1   text     44898 non-null  object
#  2   subject  44898 non-null  object
#  3   date     44898 non-null  object
#  4   label    44898 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 1.7+ MB

# %%
df.describe()
# Out:
#               label
# count  44898.000000
# mean       0.477015
# std        0.499477
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
df.duplicated().sum()
df=df.drop_duplicates()

# %%
#check for target imbalance or not
df['label'].value_counts()
# Out:
# label
# 0    23478
# 1    21211
# Name: count, dtype: int64

# %%
sns.countplot(x="label",data=df)
plt.xticks([0,1],["fake","true"])
plt.show()

# %%
#almost balance destribution
(df['label']==True).sum()
# Out:
# np.int64(21211)

# %%
df.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
duplicates=df[df["text"].duplicated(keep=False)]
duplicates.groupby("text")["label"].nunique().value_counts()
# Out:
# label
# 1    4946
# 2       1
# Name: count, dtype: int64

# %%
dup=df[df.duplicated(subset=["title", "text"],keep=False)].sort_values(["title","text"])
dup.head(10)
# Out:
#                                                    title  \
# 14160  #AnyoneButHillary: NEW POLL Shows Bernie Suppo...
# 20771  #AnyoneButHillary: NEW POLL Shows Bernie Suppo...
# 9841   #Austin: Fights Break Out Between Police and S...
# 17930  #Austin: Fights Break Out Between Police and S...
# 11756  #Berkeley CRAZY! RIOTERS CHASE And Beat People...
# 19211  #Berkeley CRAZY! RIOTERS CHASE And Beat People...
# 11755  #Berkeley IRONY ALERT! ANARCHISTS LOOT STARBUC...
# 19210  #Berkeley IRONY ALERT! ANARCHISTS LOOT STARBUC...
# 13495  #BlackLivesMatter Supporters Say No Connection...
# 20259  #BlackLivesMatter Supporters Say No Connection...
#
#                                                     text    subject  \
# 14160  Hillary may find out she needs more than black...   politics
# 20771  Hillary may find out she needs more than black...  left-news
# 9841   Commies carrying flags fought with the Austin ...   politics
# ...

# %%
df=df.drop_duplicates(subset=["title","text"])

# %%
df.shape
# Out:
# (39105, 5)

# %%
#title and text will be our main inputs
df['content']=df['title']+" "+df['text']
df.head(20)
# Out:
#                                                 title  \
# 0    Donald Trump Sends Out Embarrassing New Year’...
# 1    Drunk Bragging Trump Staffer Started Russian ...
# 2    Sheriff David Clarke Becomes An Internet Joke...
# 3    Trump Is So Obsessed He Even Has Obama’s Name...
# 4    Pope Francis Just Called Out Donald Trump Dur...
# 5    Racist Alabama Cops Brutalize Black Boy While...
# 6    Fresh Off The Golf Course, Trump Lashes Out A...
# 7    Trump Said Some INSANELY Racist Stuff Inside ...
# 8    Former CIA Director Slams Trump Over UN Bully...
# 9    WATCH: Brand-New Pro-Trump Ad Features So Muc...
# 10   Papa John’s Founder Retires, Figures Out Raci...
# 11   WATCH: Paul Ryan Just Told Us He Doesn’t Care...
# 12   Bad News For Trump — Mitch McConnell Says No ...
# 13   WATCH: Lindsey Graham Trashes Media For Portr...
# 14   Heiress To Disney Empire Knows GOP Scammed Us...
# 15   Tone Deaf Trump: Congrats Rep. Scalise On Los...
# ...

# %%
df['label'].value_counts()
# Out:
# label
# 1    21197
# 0    17908
# Name: count, dtype: int64

# %%
sns.countplot(x="label",data=df)
plt.xticks([0,1],["fake","true"])
plt.show()

# %%
df=df[['content','label']]
df.head()
print(df.shape)
# Out:
# (39105, 2)

# %%
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
df.head()
print(df.shape)
# Out:
# (39105, 2)

# %%
x=df['content']
y=df['label']
x
# Out:
# 0        Many 'lost' voters say they have found their c...
# 1        Iranian Revolutionary Guards commander, anothe...
# 2        Cambodian leader gets China's backing as West ...
# 3         Ex-KKK Grand Wizard: Maine Gov. Right To Call...
# 4        FINGER-WAGGING GRANNY HILLARY CLINTON Blows Up...
#                                ...
# 39100     Hillary’s Message To Former Miss Universe Cal...
# 39101    SENIOR CIA INTEL: “Wiretapping of Trump Transi...
# 39102    Ex-Georgian leader Saakashvili barges across U...
# 39103     Trump Stole An Idea From North Korean Propaga...
# 39104    WATCH JUDGE TELL DISRESPECTFUL GANGBANGER Taxp...
# Name: content, Length: 39105, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)
x_train.shape
# Out:
# (31284,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(
    max_features=50000,
    stop_words="english"
)

# %%
x_train_tfidf = tfidf.fit_transform(x_train)
x_train_tfidf.shape
# Out:
# (31284, 50000)

# %%
x_test_tfidf=tfidf.transform(x_test)

# %%
print(x_train_tfidf.shape)
print(x_test_tfidf.shape)
# Out:
# (31284, 50000)
# (7821, 50000)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(max_iter=1000)

# %%
model.fit(x_train_tfidf, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(x_test_tfidf)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9858074415036441

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      3582
#            1       0.98      0.99      0.99      4239
#
#     accuracy                           0.99      7821
#    macro avg       0.99      0.99      0.99      7821
# weighted avg       0.99      0.99      0.99      7821

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)
cm
# sns.heatmap(
#     cm,
#     annot=True,
#     fmt="d",
#     xticklabels=["Fake", "Real"],
#     yticklabels=["Fake", "Real"]
# )

# plt.xlabel("Predicted")
# plt.ylabel("Actual")
# plt.title("Confusion Matrix")
# plt.show()
# Out:
# array([[3503,   79],
#        [  32, 4207]])

# %%
sns.heatmap(
    cm,
    annot=True,
    xticklabels=["Fake","Real"],
    yticklabels=["Fake","Real"]
)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
